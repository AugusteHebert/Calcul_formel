# %%
#exercice 1 :

# %%
#1
def factorielle(n):
    res = 1
    while n>1 :
        res = res*n
        n = n-1
    return res

# %%
factorielle(1000)
# Out:
# ...

# %%
#2
def decomposition(n):
    s = 1
    if is_prime(n):
        return(0,n)
    if n%2 == 0 :
        t = n//2
        while t%2 == 0 :
            t = t//2
            s = s+1
    if n%2 == 1 :
        s = 0
        t = n        
    return (s,t)

# %%
decomposition (21)
# Out:
# (0, 21)

# %%
#3
def listepremier(m,n,K):
    if gcd(m,n)!=1 :
        return 'erreur'
    L = []
    for i in range(K) :
        a = 1
        while is_prime(a):
            a = a+1
        if a%100==3:
            L=L.append(a)
    return L

# %%
listepremier(18,25,10)
# Out:
# []

# %%
#4

# %%
#5

# %%
#exercice 2 :

# %%
#1
def Un(n):
    if n == 0 :
        return 0
    if n == 1 : 
        return 1
    return Un(n-1)+ Un(n-2)

# %%
Un(6)
# Out:
# 8

# %%
#2

# %%
#exercice 3 :

# %%
#1 
def premier(n):
    for k in (2,sqrt(n)): #racine carré ne donne pas un entier
        if n%k == 0 :
            return('False',k)
    return('True')

# %%
premier(7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /ext/sage/10.7/src/sage/structure/element.pyx:1968, in sage.structure.element.Element._mod_()
#    1967 try:
# -> 1968     python_op = (<object>self)._mod_
#    1969 except AttributeError:
#
# File /ext/sage/10.7/src/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__()
#     494 """
# --> 495 return self.getattr_from_category(name)
#     496
#
# File /ext/sage/10.7/src/sage/structure/element.pyx:508, in sage.structure.element.Element.getattr_from_category()
#     507     cls = P._abstract_element_class
# --> 508 return getattr_from_other_class(self, cls, name)
#     509
#
# File /ext/sage/10.7/src/sage/cpython/getattr.pyx:363, in sage.cpython.getattr.getattr_from_other_class()
#     362     dummy_error_message.name = name
# --> 363     raise AttributeError(dummy_error_message)
#     364 attribute = <object>attr
#
# AttributeError: 'sage.symbolic.ring.SymbolicRing' object has no attribute '_SageObject__custom_name'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 premier(Integer(7))
#
# Cell In[71], line 4, in premier(n)
#       2 def premier(n):
#       3     for k in (Integer(2),sqrt(n)):
# ----> 4         if n%k == Integer(0) :
#       5             return('False',k)
#       6     return('True')
#
# File /ext/sage/10.7/src/sage/rings/integer.pyx:3422, in sage.rings.integer.Integer.__mod__()
#    3420
#    3421         # Use the coercion model
# -> 3422         return coercion_model.bin_op(x, y, operator.mod)
#    3423
#    3424     def quo_rem(Integer self, other):
#
# File /ext/sage/10.7/src/sage/structure/coerce.pyx:1244, in sage.structure.coerce.CoercionModel.bin_op()
#    1242     self._record_exception()
#    1243 else:
# -> 1244     return PyObject_CallObject(op, xy)
#    1245
#    1246 if op is mul:
#
# File /ext/sage/10.7/src/sage/structure/element.pyx:1935, in sage.structure.element.Element.__mod__()
#    1933 cdef int cl = classify_elements(left, right)
#    1934 if HAVE_SAME_PARENT(cl):
# -> 1935     return (<Element>left)._mod_(right)
#    1936 if BOTH_ARE_ELEMENT(cl):
#    1937     return coercion_model.bin_op(left, right, mod)
#
# File /ext/sage/10.7/src/sage/structure/element.pyx:1970, in sage.structure.element.Element._mod_()
#    1968     python_op = (<object>self)._mod_
#    1969 except AttributeError:
# -> 1970     raise bin_op_exception('%', self, other)
#    1971 else:
#    1972     return python_op(other)
#
# TypeError: unsupported operand parent(s) for %: 'Symbolic Ring' and 'Symbolic Ring'

# %%
premier(4)
# Out:
# ('False', 2)

# %%
#2
def niemepremier(n):
    r = 0
    a = 1
    while r!=n : 
        a = a+1
        if is_prime(a):
            r=r+1
        
    return(a)

# %%
#le 1000 nombre premier est : 7919
niemepremier(1000)
# Out:
# 7919

# %%
#3
def divpremier(n):
    L = []
    a = n
    while a>1:
        if is_prime(a):
            if n%a == 0:
                L = L.append(a)
        a = a-1
    return L

# %%
divpremier(14)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 divpremier(Integer(14))
#
# Cell In[87], line 8, in divpremier(n)
#       6     if is_prime(a):
#       7         if n%a == Integer(0):
# ----> 8             L = L.append(a)
#       9     a = a-Integer(1)
#      10 return L
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
#4

# %%
#exercice 4 :

# %%
#1
def temoin(n,a):
    if jacobi_symbol(a,n)%n == a^((n-1)/2) :
        return('FAUX')
    return('VRAI')

# %%
temoin(7,3)
# Out:
# 'VRAI'

# %%
#2
def Solovay_strassen(n,k):
    while k>0 :
        a = randint(2,n-1)
        if r == temoin(n,a) :
            retur(n ,'n est pas premier')
        k = k-1
    return (n,'est peut-etre premier')

# %%
Solovay_strassen(9,3)
# Out:
# (9, 'est peut-etre premier')

# %%
#3

# %%
#exercice 5 :

# %%
#1
def vigenere(cle,texte):
