# %%
#Ex 2 : 1 
def u(n):
    if n== 0 :
        return 0
    if n== 1 : 
        return 1
    if n == 2:
        return 1
    return u(n-1)+u(n-2)

# %%
#Ex 1 : 1
def factorielle(n):
    if n == 0 : 
        return 1
    return factorielle(n-1)*n

# %%
factorielle(1000)
# Out:
# ...

# %%
#Ex 1 : 2
def decomposition(n):
    s = 0
    t = n
    while t % 2 == 0 : 
        s+=1
        t = t//2
    return (s,t)

# %%
#Ex 1 : 3
def programme3(m,n,K):
    if gcd(m,n) != 1 :
        return "error"
    c=0
    i=0
    L=[]
    while c < K :
        if is_prime(i) and (i % n) == m :
            L.append(i)
            c+=1
            i+=1
        i+=1
    return L

# %%
#Ex 1 : 5 
power_mod(10,10*10,7)
# Out:
# 4

# %%
#Ex 2 : 2 
def fino(n):
    a,b = 0,1
    for _ in range(n):
        a,b= b, (a+b) % 10
    return a

# %%
fino(10**7)
# Out:
# 5

# %%
#Ex 3 : 1
def programme331(n):
    if is_prime(n):
        return True
    j=2
    while not (is_prime(j) and (n % j == 0)):
        j+=1
    return (False,j)

# %%
#Ex 3 : 2
def n_iemeprime(n): 
    c=0
    k=1
    while True:
        k+=1
        if is_prime(k) :
            c+=1
            if c == n :
                return k

# %%
#Ex 6 : 1
def premier_aleatoire(K):
    a = ZZ.random_element(10**K,10**(K+1))
    while not is_prime(a) :
        a = ZZ.random_element(10**K,10**(K+1))
    return a

# %%
n_iemeprime(1000)
# Out:
# 7919

# %%
#Ex 3 : 3
def programme333(n):
    L=[]
    p=2
    while p < sqrt(n) :
        if  n % p == 0 :
            L.append(p)
        p = next_prime(p)
    return L

# %%
#Ex 3 : 4
def programme334(n):
    L = sorted(programme333(n))
    res = []
    l = len(L)
    for j in range(l): 
        c=0
        d = n
        while L[j] % d == 0:
            c+=1
            d=d//L[j]
        res.append([L[j],c])
    return res

# %%
#Ex 5: 1
def vigenere(cle,texte):
    long_t = len(texte)
    long_c = len(cle)
    T = code_ascii(texte)
    C = code_ascii(cle)
    Codage = ''
    for i in range(long_t):
        j = i%long_c
        c= T[i]+ C[j]-65
        if c > 90 :
            c-=26
        Codage += chr(c)
    return Codage

# %%
#Ex 5 : 2
def inverse(cle,texte):
    long_t = len(texte)
    long_c = len(cle)
    T = code_ascii(texte)
    deCodage = ''
    j=0
    i=0
    while i < long_t:
        j=0
        while j < long_c :
            c= T[i]- ord(cle[j])-65
            if c < 65 :
                c+=26
            Codage += chr(c)
            j += 1
            i += 1
    return deCodage

# %%
#Ex 4 : 1
def programme441(a,n):
    if is_prime(n):
        return False
    if a < 2 or a > n-1 :
        return False
    return jacobi_symbol(a,n) % n != power_mod(a,((n-1)/2),n)

# %%
#Ex 1 : 4
def tiplet():
    L=[]
    for c in range(25):
        for a in range(25) :
            for b in range(25):
                if a**2 + b**2 == c**2 :
                    L.append([a,b,c])
    return L

# %%
#Ex 4: 2
def Solovay_Strassen(n,k):
    c = 1
    while c != k :
        a = ZZ.random_element(2,n)
        if programme441(a,n) :
            return "n n'est pas premier"
        c+=1
    return "n est peut-être premier"

# %%
#Ex 4: 3
def listimp(n):
    L=[]
    for a in range(3,10**n):
        if a % 2 == 1:
            if Solovay_Strassen(a,2) == "n est peut-être premier" :
                L.append(a)
    return L

# %%
listimp(10**5) #a executer soit même par soucis de place suite question 3 exos 4

# %%
#Ex 6 : 2

def cle(K):
    p = premier_aleatoire(K)
    q = premier_aleatoire(K)
    phi =(p-1)*(q-1)
    e = ZZ.random_element(2,phi)
    while gcd(e,phi) !=1 :
        e = ZZ.random_element(2,phi)
    d = xgcd(e,phi)[1]
    return [[p*q,e],[d,phi]]

# %%
# Ex 6 : 3 
power_mod(2718281828,691,708641*817787)
# Out:
# 44749617721

# %%
# Ex 6 : 4
def programme664(m,L):
    return power_mod(m,L[1],L[0])

# %%
# Ex 6: 5
def programme665(C,L):
    n = L[0]
    e = L[1]
    p=factor(n)[0][0]
    q=factor(n)[1][0]
    phi =(p-1)*(q-1)
    d = xgcd(e,phi)[1]
    return power_mod(C,d,n)

# %%
# Ex 6: 6 
programme665(279148699747,[708641*87787,691])
# Out:
# 3387999238
