# %% [markdown]
# ### Le programme suivant calcule s et t tels que 2^s t=n-1

# %%
def decompo(n):
    t=n-1
    s=0
    while t%2==0:
        s+=1
        t=t//2
    return (s,t)

# %% [markdown]
# # Le programme suivant vérifie si a est un témoin de Miller pour a. S'il renvoie faux, alors a est un témoin de Miller pour n (le choix de l'énoncé n'est pas très judicieux).

# %%
def temoin_Miller(n,a):
    s,t=decompo(n)
    if power_mod(a,t,n)==1:
        return True
    for i in [0..s-1]:
        if power_mod(a,t*2^i,n)==n-1:
            return True
    return False

# %% [markdown]
# # Le programme suivant fait la même chose que le précédent mais il est un peu optimisé. Au lieu de calculer a^(t*2^i)%n
# # depuis le début, il calcule b=a^t%n puis il calcule a^(t*2^i)%n en élevant b au carré successivement.

# %%
def temoin_Miller_opti(n,a):
    s,t=decompo(n)
    b=power_mod(a,t,n)
    if b==1:
        return True
    if b==n-1:
        return True
    for i in [0..s-2]:
        b=(b^2)%n
        if b==n-1:
            return True
    return False

# %%
N=10^5

# %% [markdown]
# ### Les deux "programmes" suivants déterminent la liste des éléments impairs composés entre 9 et 100000 pour lesquels 13 n'est pas un témoin de Miller. On constate qu'il y en a peu.

# %%
L=[]
for i in range(9,N,2):
    if temoin_Miller(i,13)==True and not is_prime(i):
        L.append(i)

# %%
L_opti=[]
for i in range(9,N,2):
    if temoin_Miller_opti(i,13)==True and not is_prime(i):
        L_opti.append(i)

# %%
len(L),L
# Out:
# (24,
#  [85,
#   1099,
#   5149,
#   7107,
#   8911,
#   9637,
#   13019,
#   14491,
#   17803,
#   19757,
#   20881,
#   22177,
#   23521,
#   26521,
#   35371,
#   44173,
#   45629,
#   54097,
#   56033,
#   57205,
#   75241,
#   83333,
#   85285,
#   86347])

# %%
L==L_opti
# Out:
# True

# %% [markdown]
# ### Les deux tests suivants font le test de Miller-Rabin, pour savoir si n est premier. On choisit des éléments au hasard entre 2 et n-2.Si on tombe sur un témoin de Miller, on s'arrête car on sait que n est premier. Sinon, on continue. Au bout de k essais, on s'arrête et on dit que le nombre est peut-être premier. La différence entre les deux programmes est que l'un utilise temoin_Miller et l'autre utilise temoin_Miller_opti.

# %%
def test_MR(n,k):
    for i in [1..k]:
        a=ZZ.random_element(2,n-2)
        if temoin_Miller(n,a)==False:
            return False
    return True

# %%
def test_MR_opti(n,k):
    for i in [1..k]:
        a=ZZ.random_element(2,n-2)
        if temoin_Miller_opti(n,a)==False:
            return False
    return True

# %% [markdown]
# ### Les deux procédures suivantes déterminent la liste des nombres composés impairs entre 9 et 100000 qui font échouer le test de Miller-Rabin avec un seul essai (k=1). Cette liste est variable car les tests utilisés piochent des nombres au hasard.

# %%
L=[]
for i in range(9,N,2):
    if test_MR(i,1)==True and not is_prime(i):
        L.append(i)

# %%
L_opti=[]
for i in range(9,N,2):
    if test_MR_opti(i,1)==True and not is_prime(i):
        L_opti.append(i)

# %%
len(L),L
# Out:
# (36,
#  [595,
#   1339,
#   2047,
#   2359,
#   2651,
#   3097,
#   3781,
#   5713,
#   6943,
#   7601,
#   9881,
#   14981,
#   17031,
#   17611,
#   17767,
#   18103,
#   22177,
#   25351,
#   26599,
#   27133,
#   28939,
#   29539,
#   30857,
#   32509,
#   36841,
#   38081,
#   39553,
#   42127,
#   43081,
#   43435,
#   44801,
#   45811,
#   64177,
#   69231,
#   88357,
#   90751])

# %%
len(L_opti),L
# Out:
# (34, [35371])

# %% [markdown]
# ### La procédure suivante détermine la même liste qu'avant, mais avec deux essais au lieu d'un. La liste est très réduite. Avec trois essais au lieu de deux, j'obtiens des listes à 0 ou 1 élément, avec 0 la plupart du temps.

# %%
L=[]
for i in range(9,N,2):
    if test_MR(i,2)==True and not is_prime(i):
        L.append(i)

# %%
L
# Out:
# [31417, 81317]

# %% [markdown]
# ### La procédure suivante vérifie que tous les nombres impairs n entre 9 et 100000 pour lesquels le test dit que n est composé, sont composés. On ne constate pas d'erreur.

# %%
M=[]
for i in range(9,N,2):
    if test_MR(i,1)==False and is_prime(i):
        M.append(i)

# %%
M_opti=[]
for i in range(9,N,2):
    if test_MR_opti(i,1)==False and is_prime(i):
        M.append(i)

# %%
M
# Out:
# []

# %%
M_opti
# Out:
# []

# %% [markdown]
# ### Le programme suivant détermine la proportion de nombres entre 2 et k-2 qui sont ne sont pas des témoins de Miller,  pour un k donné.

# %%
def proportion(k):
    a=0
    b=0
    for i in [2..k-2]:
        b+=1
        if temoin_Miller(k,i):
            a+=1
    return n(a/(k-3))

# %% [markdown]
# ### On vérifie pour k premier entre 9 et 1000 que la proportion de nombres qui ne sont pas des témoins de Miller est bien 1 : aucun nombre entre 2 et k-2 est un témoin de Miller (de non-primalité). C'est attendu.

# %%
R=[]
for i in [9..N//100]:
    if is_prime(i):
        R.append(proportion(i))
R
# Out:
# [1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000,
#  1.00000000000000]

# %% [markdown]
# ### On détermine la proportion de non-témoin de Miller pour chaque nombre composé impair entre 9 et 1000. On constate que la plupart des nombres n'ont que des témoins de Miller. Le maximum que l'on obtient est 0.22, pour 703. On constate également que seulement 6 nombres ont plus de 10% de non-témoins de Miller. Ceci explique pourquoi le test fonctionne très bien empiriquement. En fait la borne de 1/4 donnée par le théorème de Miller est beaucoup trop élevée pour la plupart des nombres.

# %%
S=[]
for i in range(9,N//100,2):
    if is_prime(i)==False:
        S.append((i,proportion(i)))
S
# Out:
# [(9, 0.000000000000000),
#  (15, 0.000000000000000),
#  (21, 0.000000000000000),
#  (25, 0.0909090909090909),
#  (27, 0.000000000000000),
#  (33, 0.000000000000000),
#  (35, 0.000000000000000),
#  (39, 0.000000000000000),
#  (45, 0.000000000000000),
#  (49, 0.0869565217391304),
#  (51, 0.000000000000000),
#  (55, 0.000000000000000),
#  (57, 0.000000000000000),
#  (63, 0.000000000000000),
#  (65, 0.0645161290322581),
#  (69, 0.000000000000000),
#  (75, 0.000000000000000),
#  (77, 0.000000000000000),
#  (81, 0.000000000000000),
#  (85, 0.0487804878048781),
#  (87, 0.000000000000000),
#  (91, 0.181818181818182),
#  (93, 0.000000000000000),
#  (95, 0.000000000000000),
#  (99, 0.000000000000000),
#  (105, 0.000000000000000),
#  (111, 0.000000000000000),
#  (115, 0.000000000000000),
#  (117, 0.000000000000000),
#  (119, 0.000000000000000),
#  (735, 0.000000000000000),
#  (737, 0.000000000000000),
#  (741, 0.000000000000000),
#  (745, 0.00539083557951483),
#  (747, 0.000000000000000),
#  (749, 0.000000000000000),
#  (753, 0.000000000000000),
#  (755, 0.000000000000000),
#  (759, 0.000000000000000),
#  (763, 0.0210526315789474),
#  (765, 0.000000000000000),
#  (767, 0.000000000000000),
#  (771, 0.000000000000000),
#  (775, 0.00518134715025907),
#  (777, 0.000000000000000),
#  (779, 0.000000000000000),
#  (781, 0.0616966580976864),
#  (783, 0.000000000000000),
#  (785, 0.00511508951406650),
#  (789, 0.000000000000000),
#  (791, 0.000000000000000),
#  (793, 0.0658227848101266),
#  (795, 0.000000000000000),
#  (799, 0.000000000000000),
#  (801, 0.000000000000000),
#  (803, 0.000000000000000),
#  (805, 0.00498753117206983),
#  (807, 0.000000000000000),
#  (813, 0.000000000000000),
#  (815, 0.000000000000000),
#  (817, 0.0196560196560197),
#  (819, 0.000000000000000),
#  (825, 0.000000000000000),
#  (831, 0.000000000000000),
#  (833, 0.000000000000000),
#  (835, 0.000000000000000),
#  (837, 0.000000000000000),
#  (841, 0.0310262529832936),
#  (843, 0.000000000000000),
#  (845, 0.00475059382422803),
#  (847, 0.00473933649289100),
#  (849, 0.000000000000000),
#  (851, 0.000000000000000),
#  (855, 0.000000000000000),
#  (861, 0.00932400932400932),
#  (865, 0.00464037122969838),
#  (867, 0.000000000000000),
#  (869, 0.000000000000000),
#  (871, 0.0184331797235023),
#  (873, 0.000000000000000),
#  (875, 0.000000000000000),
#  (879, 0.000000000000000),
#  (885, 0.000000000000000),
#  (889, 0.0180586907449210),
#  (891, 0.00900900900900901),
#  (893, 0.000000000000000),
#  (895, 0.000000000000000),
#  (897, 0.000000000000000),
#  (899, 0.000000000000000),
#  (901, 0.00445434298440980),
#  (903, 0.000000000000000),
#  (905, 0.00443458980044346),
#  (909, 0.000000000000000),
#  (913, 0.000000000000000),
#  (915, 0.000000000000000),
#  (917, 0.000000000000000),
#  (921, 0.000000000000000),
#  (923, 0.000000000000000),
#  (925, 0.0173535791757050),
#  (927, 0.000000000000000),
#  (931, 0.0172413793103448),
#  (933, 0.000000000000000),
#  (935, 0.000000000000000),
#  (939, 0.000000000000000),
#  (943, 0.000000000000000),
#  (945, 0.000000000000000),
#  (949, 0.0549682875264271),
#  (951, 0.000000000000000),
#  (955, 0.000000000000000),
#  (957, 0.000000000000000),
#  (959, 0.000000000000000),
#  (961, 0.0292275574112735),
#  (963, 0.000000000000000),
#  (965, 0.00415800415800416),
#  (969, 0.000000000000000),
#  (973, 0.0164948453608247),
#  (975, 0.000000000000000),
#  (979, 0.000000000000000),
#  (981, 0.000000000000000),
#  (985, 0.00407331975560081),
#  (987, 0.000000000000000),
#  (989, 0.000000000000000),
#  (993, 0.000000000000000),
#  (995, 0.000000000000000),
#  (999, 0.000000000000000)]

# %%
S=[]
for i in range(9,N//100,2):
    if is_prime(i)==False:
        S.append(proportion(i))
S
# Out:
# [0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0909090909090909,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0869565217391304,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0645161290322581,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0487804878048781,
#  0.000000000000000,
#  0.181818181818182,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0677966101694915,
#  0.000000000000000,
#  0.0163934426229508,
#  0.000000000000000,
#  0.123076923076923,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0281690140845070,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0602409638554217,
#  0.000000000000000,
#  0.0232558139534884,
#  0.000000000000000,
#  0.000000000000000,
#  0.0219780219780220,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0198019801980198,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0747663551401869,
#  0.000000000000000,
#  0.0183486238532110,
#  0.000000000000000,
#  0.0350877192982456,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0655737704918033,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0625000000000000,
#  0.000000000000000,
#  0.0152671755725191,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0489510489510490,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0536912751677852,
#  0.000000000000000,
#  0.0132450331125828,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0496894409937888,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.142011834319527,
#  0.0117647058823529,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0446927374301676,
#  0.000000000000000,
#  0.0110497237569061,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0106951871657754,
#  0.000000000000000,
#  0.0104712041884817,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0400000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00947867298578199,
#  0.0377358490566038,
#  0.000000000000000,
#  0.0277777777777778,
#  0.000000000000000,
#  0.000000000000000,
#  0.00904977375565611,
#  0.000000000000000,
#  0.107142857142857,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0343347639484979,
#  0.000000000000000,
#  0.000000000000000,
#  0.00847457627118644,
#  0.000000000000000,
#  0.108786610878661,
#  0.000000000000000,
#  0.00829875518672199,
#  0.000000000000000,
#  0.00816326530612245,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00796812749003984,
#  0.000000000000000,
#  0.0314960629921260,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0380228136882129,
#  0.000000000000000,
#  0.00754716981132075,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00738007380073801,
#  0.000000000000000,
#  0.000000000000000,
#  0.0290909090909091,
#  0.000000000000000,
#  0.0287769784172662,
#  0.0143369175627240,
#  0.00711743772241993,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0273037542662116,
#  0.000000000000000,
#  0.00675675675675676,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00321543408360129,
#  0.000000000000000,
#  0.00638977635782748,
#  0.000000000000000,
#  0.000000000000000,
#  0.0252365930599369,
#  0.000000000000000,
#  0.0186915887850467,
#  0.000000000000000,
#  0.0123456790123457,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0718562874251497,
#  0.000000000000000,
#  0.0236686390532544,
#  0.000000000000000,
#  0.00586510263929619,
#  0.000000000000000,
#  0.00583090379008746,
#  0.000000000000000,
#  0.000000000000000,
#  0.0288184438040346,
#  0.000000000000000,
#  0.228571428571429,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00561797752808989,
#  0.000000000000000,
#  0.0222841225626741,
#  0.000000000000000,
#  0.00554016620498615,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00539083557951483,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0210526315789474,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00518134715025907,
#  0.000000000000000,
#  0.000000000000000,
#  0.0616966580976864,
#  0.000000000000000,
#  0.00511508951406650,
#  0.000000000000000,
#  0.000000000000000,
#  0.0658227848101266,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00498753117206983,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0196560196560197,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0310262529832936,
#  0.000000000000000,
#  0.00475059382422803,
#  0.00473933649289100,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00932400932400932,
#  0.00464037122969838,
#  0.000000000000000,
#  0.000000000000000,
#  0.0184331797235023,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0180586907449210,
#  0.00900900900900901,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00445434298440980,
#  0.000000000000000,
#  0.00443458980044346,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0173535791757050,
#  0.000000000000000,
#  0.0172413793103448,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0549682875264271,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.0292275574112735,
#  0.000000000000000,
#  0.00415800415800416,
#  0.000000000000000,
#  0.0164948453608247,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.00407331975560081,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000,
#  0.000000000000000]

# %%
max(S)
# Out:
# 0.228571428571429

# %%
M=[]
for i in S:
    if i>=0.1:
        M.append(i)

# %%
M
# Out:
# [0.181818181818182,
#  0.123076923076923,
#  0.142011834319527,
#  0.107142857142857,
#  0.108786610878661,
#  0.228571428571429]
